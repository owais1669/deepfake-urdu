# %%
cd /content/drive/MyDrive/Deepfake/urdu-deepfake
# Out:
# /content/drive/MyDrive/Deepfake/urdu-deepfake

# %%
ls
# Out:
# dataset/                          deepfake-whisper-features-main/  Untitled0.ipynb
# deepfake_detection_dataset_urdu/  lcnn_lfcc.ipynb

# %%
cd deepfake-whisper-features-main
# Out:
# [Errno 2] No such file or directory: 'deepfake-whisper-features-main'
# /content/drive/MyDrive/Deepfake/urdu-deepfake/deepfake-whisper-features-main

# %%
# !pip install asteroid_filterbanks

# %%
ls
# Out:
# configs/  install.sh  __pycache__/  src/  train_model.py  Untitled0.ipynb

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="torchaudio.functional.functional")

# %%
# !python train_model.py --dataset_path "/content/drive/MyDrive/Deepfake/urdu-deepfake/deepfake_detection_dataset_urdu" --feature_type "mfcc" --model_name "lcnn" --batch_size 32 --epochs 10 --learning_rate 0.0001
# Out:
# /usr/local/lib/python3.10/dist-packages/torchaudio/functional/functional.py:584: UserWarning: At least one mel filterbank has all zero values. The value for `n_mels` (128) may be set too high. Or, the value for `n_freqs` (257) may be set too low.
#   warnings.warn(
# mfcc
# 0.0001
# lcnn
# 32
# 10
# 10
# 10
# 10
# 10
# sd
# sd
# sd
# sd
# sd
